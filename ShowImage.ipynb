# %%
cd /ads-nfs/sixuegong/ImageNet/Cropped/Validation
# Out:
# /ads-nfs/sixuegong/ImageNet/Cropped/Validation

# %%
cd n04350905
# Out:
# /ads-nfs/sixuegong/ImageNet/Cropped/Validation/n04350905

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("ILSVRC2012_val_00046726_1.JPEG")
imgplot = plt.imshow(img)
